# %%
spark.conf.set("fs.azure.account.auth.type.f1dlnagsa.dfs.core.windows.net", "SAS")
spark.conf.set("fs.azure.sas.token.provider.type.f1dlnagsa.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.sas.FixedSASTokenProvider")
spark.conf.set("fs.azure.sas.fixed.token.f1dlnagsa.dfs.core.windows.net", dbutils.secrets.get(scope="<scope>", key="<sas-token-key>"))

# %%
dbutils.fs.ls("abfss://demo@f1dlnagsa.dfs.core.windows.net")
# Out:
# [FileInfo(path='abfss://demo@f1dlnagsa.dfs.core.windows.net/circuits.csv', name='circuits.csv', size=10044, modificationTime=1741976327000)]
